# %% [markdown]
# # Importing Pandas

# %%
# Start by importing Pandas (CLARIFICATION: from python, not from south central China)
import pandas as pd

# %% [markdown]
# # Creating a Series

# %%
# Create a Series of three numbers: 10, 20 and 10.

series_01 = pd.Series([10, 20, 10])
print(series_01)
# Out:
# 0    10
# 1    20
# 2    10
# dtype: int64

# %%
# Create a Series of three objects: 'red, 'blue', 'red'

series_02 = pd.Series(['red', 'blue', 'red'])
print(series_02)
# Out:
# 0     red
# 1    blue
# 2     red
# dtype: object

# %% [markdown]
# # Creating a DataFrame

# %%
# Create an empty DataFrame, called 'df'.

df = pd.DataFrame()

# %%
# Create a new column on the dataframe, and assign it the first Series you created.

df['column_01'] = series_01

# %%
# Create another column on the dataframe, and assign it the second Series you created.

df['column_02'] = series_02

# %% [markdown]
# # Reading a DataFrame

# %%
# Read the 'avengers.csv" into a DataFrame, called 'avengers'. 
# The path the file is '../data/avengers.csv"

avengers = pd.read_csv('/home/boturon/proj/ldssa/learning-units/units/01-dataframes-and-series/data/avengers.csv')

# %% [markdown]
# # Previewing a DataFrame

# %%
# Show the first 5 rows of the DataFrame.

avengers.head()
# Out:
#                                                  URL  \
# 0      http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 1  http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 2  http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 3  http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 4   http://marvel.wikia.com/Thor_Odinson_(Earth-616)
#
#                     Name/Alias  Appearances Current?  Gender  \
# 0    Henry Jonathan "Hank" Pym         1269      YES    MALE
# 1               Janet van Dyne         1165      YES  FEMALE
# 2  Anthony Edward "Tony" Stark         3068      YES    MALE
# 3          Robert Bruce Banner         2089      YES    MALE
# 4                 Thor Odinson         2402      YES    MALE
#
#   Probationary Introl Full/Reserve Avengers Intro  Year  Years since joining  \
# 0                 NaN                      Sep-63  1963                   52
# 1                 NaN                      Sep-63  1963                   52
# 2                 NaN                      Sep-63  1963                   52
# 3                 NaN                      Sep-63  1963                   52
# 4                 NaN                      Sep-63  1963                   52
#
#   Honorary                        ...                         Return1 Death2  \
# 0     Full                        ...                              NO    NaN
# 1     Full                        ...                             YES    NaN
# 2     Full                        ...                             YES    NaN
# 3     Full                        ...                             YES    NaN
# 4     Full                        ...                             YES    YES
#
#   Return2 Death3 Return3 Death4 Return4 Death5 Return5  \
# 0     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 1     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 2     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 3     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 4      NO    NaN     NaN    NaN     NaN    NaN     NaN
#
#                                                Notes
# 0  Merged with Ultron in Rage of Ultron Vol. 1. A...
# 1  Dies in Secret Invasion V1:I8. Actually was se...
# 2  Death: "Later while under the influence of Imm...
# 3  Dies in Ghosts of the Future arc. However "he ...
# 4  Dies in Fear Itself brought back because that'...
#
# [5 rows x 21 columns]

# %%
# Show the first 20 rows of the DataFrame. 
# Read the Pandas documentation for '.head()' to learn how.

avengers.head(20)
# Out:
#                                                   URL  \
# 0       http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 1   http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 2   http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 3   http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 4    http://marvel.wikia.com/Thor_Odinson_(Earth-616)
# 5   http://marvel.wikia.com/Richard_Jones_(Earth-616)
# 6   http://marvel.wikia.com/Steven_Rogers_(Earth-616)
# 7    http://marvel.wikia.com/Clint_Barton_(Earth-616)
# 8   http://marvel.wikia.com/Pietro_Maximoff_(Earth...
# 9   http://marvel.wikia.com/Wanda_Maximoff_(Earth-...
# 10  http://marvel.wikia.com/Jacques_Duquesne_(Eart...
# 11       http://marvel.wikia.com/Hercules_(Earth-616)
# 12     http://marvel.wikia.com/T%27Challa_(Earth-616)
# 13         http://marvel.wikia.com/Vision_(Earth-616)
# 14               http://marvel.wikia.com/Dane_Whitman
# 15  http://marvel.wikia.com/Natalia_Romanova_(Eart...
# 16        http://marvel.wikia.com/Mantis_(Earth-616)#
# 17   http://marvel.wikia.com/Henry_McCoy_(Earth-616)#
# 18  http://marvel.wikia.com/Heather_Douglas_(Earth...
# 19  http://marvel.wikia.com/Patricia_Walker_(Earth...
#
#                      Name/Alias  Appearances Current?  Gender  \
# 0     Henry Jonathan "Hank" Pym         1269      YES    MALE
# 1                Janet van Dyne         1165      YES  FEMALE
# 2   Anthony Edward "Tony" Stark         3068      YES    MALE
# 3           Robert Bruce Banner         2089      YES    MALE
# 4                  Thor Odinson         2402      YES    MALE
# 5        Richard Milhouse Jones          612      YES    MALE
# 6                 Steven Rogers         3458      YES    MALE
# 7        Clinton Francis Barton         1456      YES    MALE
# 8               Pietro Maximoff          769      YES    MALE
# 9                Wanda Maximoff         1214      YES  FEMALE
# 10             Jacques Duquesne          115       NO    MALE
# 11                     Heracles          741      YES    MALE
# 12                     T'Challa          780       NO    MALE
# 13         Victor Shade (alias)         1036      YES    MALE
# 14                 Dane Whitman          482       NO    MALE
# 15   Natalia Alianovna Romanova         1112      YES  FEMALE
# 16                       Brandt          160       NO  FEMALE
# 17               Henry P. McCoy         1886       NO    MALE
# 18              Heather Douglas          332       NO  FEMALE
# 19                 Patsy Walker          557       NO  FEMALE
#
#    Probationary Introl Full/Reserve Avengers Intro  Year  Years since joining  \
# 0                  NaN                      Sep-63  1963                   52
# 1                  NaN                      Sep-63  1963                   52
# 2                  NaN                      Sep-63  1963                   52
# 3                  NaN                      Sep-63  1963                   52
# 4                  NaN                      Sep-63  1963                   52
# 5                  NaN                      Sep-63  1963                   52
# 6                  NaN                      Mar-64  1964                   51
# 7                  NaN                      May-65  1965                   50
# 8                  NaN                      May-65  1965                   50
# 9                  NaN                      May-65  1965                   50
# 10                 NaN                      Sep-65  1965                   50
# 11                 NaN                      Oct-67  1967                   48
# 12                 NaN                      May-68  1968                   47
# 13                 NaN                      Nov-68  1968                   47
# 14                 NaN                      Dec-69  1969                   46
# 15                 NaN                      May-73  1973                   42
# 16                 NaN                      Aug-73  1973                   42
# 17              Jul-75                      Sep-76  1976                   39
# 18              Jul-75                      Sep-76  1976                   39
# 19              Nov-75                      Sep-76  1976                   39
#
#     Honorary                        ...                         Return1  \
# 0       Full                        ...                              NO
# 1       Full                        ...                             YES
# 2       Full                        ...                             YES
# 3       Full                        ...                             YES
# 4       Full                        ...                             YES
# 5   Honorary                        ...                             NaN
# 6       Full                        ...                             YES
# 7       Full                        ...                             YES
# 8       Full                        ...                             YES
# 9       Full                        ...                             YES
# 10      Full                        ...                             YES
# 11      Full                        ...                             NaN
# 12      Full                        ...                             NaN
# 13      Full                        ...                             YES
# 14      Full                        ...                             NaN
# 15      Full                        ...                             YES
# 16      Full                        ...                             YES
# 17      Full                        ...                             NaN
# 18      Full                        ...                             YES
# 19      Full                        ...                             YES
#
#    Death2 Return2 Death3 Return3 Death4 Return4 Death5 Return5  \
# 0     NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 1     NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 2     NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 3     NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 4     YES      NO    NaN     NaN    NaN     NaN    NaN     NaN
# 5     NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 6     NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 7     YES     YES    NaN     NaN    NaN     NaN    NaN     NaN
# 8     NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 9     NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 10    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 11    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 12    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 13    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 14    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 15    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 16    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 17    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 18    YES     YES    NaN     NaN    NaN     NaN    NaN     NaN
# 19    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
#
#                                                 Notes
# 0   Merged with Ultron in Rage of Ultron Vol. 1. A...
# 1   Dies in Secret Invasion V1:I8. Actually was se...
# 2   Death: "Later while under the influence of Imm...
# 3   Dies in Ghosts of the Future arc. However "he ...
# 4   Dies in Fear Itself brought back because that'...
# 5                                                 NaN
# 6     Dies at the end of Civil War. Later comes back.
# 7   Dies in exploding Kree ship in Averngers Vol. ...
# 8   Dies in House of M Vol 1 Issue 7. Later comes ...
# 9   Dies in Uncanny_Avengers_Vol_1_14. Later comes...
# 10  Dies in Avengers_Vol_1_130. Brought back by th...
# 11                                                NaN
# 12                                                NaN
# 13  Dies in Avengers_Vol_1_500. Is eventually rebu...
# 14                                                NaN
# 15  Killed by The Hand. Later revived with The Sto...
# 16  Dies in Silver_Surfer_Vol_3_3. Actually "fragm...
# 17                                                NaN
# 18  Dies in Defenders_Vol_1_152. Later 'Obtained a...
# 19  Died during time on Defenders. Eventually ress...
#
# [20 rows x 21 columns]

# %%
# Show the last 5 rows of the DataFrame.

avengers.tail()
# Out:
#                                                    URL      Name/Alias  \
# 168   http://marvel.wikia.com/Eric_Brooks_(Earth-616)#     Eric Brooks
# 169  http://marvel.wikia.com/Adam_Brashear_(Earth-6...   Adam Brashear
# 170  http://marvel.wikia.com/Victor_Alvarez_(Earth-...  Victor Alvarez
# 171     http://marvel.wikia.com/Ava_Ayala_(Earth-616)#       Ava Ayala
# 172         http://marvel.wikia.com/Kaluu_(Earth-616)#           Kaluu
#
#      Appearances Current?  Gender Probationary Introl  \
# 168          198      YES    MALE                 NaN
# 169           29      YES    MALE                 NaN
# 170           45      YES    MALE                 NaN
# 171           49      YES  FEMALE                 NaN
# 172           35      YES    MALE                 NaN
#
#     Full/Reserve Avengers Intro  Year  Years since joining Honorary  ...   \
# 168                      13-Nov  2013                    2     Full  ...
# 169                      14-Jan  2014                    1     Full  ...
# 170                      14-Jan  2014                    1     Full  ...
# 171                      14-Jan  2014                    1     Full  ...
# 172                      15-Jan  2015                    0     Full  ...
#
#     Return1 Death2 Return2 Death3 Return3 Death4 Return4 Death5 Return5 Notes
# 168     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN   NaN
# 169     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN   NaN
# 170     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN   NaN
# 171     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN   NaN
# 172     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN   NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# # Shape of a DataFrame

# %%
# Show the shape of the DataFrame.

avengers.shape
# Out:
# (173, 21)

# %% [markdown]
# # Data types in a DataFrame

# %%
# Show the data types of the DataFrame

avengers.dtypes
# Out:
# URL                            object
# Name/Alias                     object
# Appearances                     int64
# Current?                       object
# Gender                         object
# Probationary Introl            object
# Full/Reserve Avengers Intro    object
# Year                            int64
# Years since joining             int64
# Honorary                       object
# Death1                         object
# Return1                        object
# Death2                         object
# Return2                        object
# Death3                         object
# Return3                        object
# Death4                         object
# Return4                        object
# Death5                         object
# Return5                        object
# Notes                          object
# dtype: object

# %% [markdown]
# # Setting the index of a DataFrame

# %%
# Set the index of the DataFrame as 'Years since joining'.

avengers.set_index('Years since joining', inplace=True)

# %% [markdown]
# # Sorting the index of a DataFrame

# %%
# Sort the index of the DataFrame as descending.
# Read the Pandas documentation for 'sort_index()' to learn how.

avengers.sort_index(ascending=False, inplace=True)

# %% [markdown]
# # Resetting the index of a DataFrame

# %%
# Reset the index of the DataFrame.

avengers.reset_index(inplace=True)
